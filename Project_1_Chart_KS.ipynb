# %%
import pandas as pd
import numpy as np
from pprint import pprint
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd.read_csv('complete_data_EM_3.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Acousticness  Danceability  Duration Ms  Energy  \
# 0           1       0.11788        0.7372     155645.8  0.6806
# 1           2       0.11788        0.7372     155645.8  0.6806
# 2           3       0.11788        0.7372     155645.8  0.6806
# 3           4       0.11788        0.7372     155645.8  0.6806
# 4           5       0.11788        0.7372     155645.8  0.6806
#
#    Instrumentalness  Liveness  Loudness  Popularity  Speechiness     Tempo  \
# 0               0.0    0.1598    -5.112        72.0        0.279  118.2184
# 1               0.0    0.1598    -5.112        72.0        0.279  118.2184
# 2               0.0    0.1598    -5.112        72.0        0.279  118.2184
# 3               0.0    0.1598    -5.112        72.0        0.279  118.2184
# 4               0.0    0.1598    -5.112        72.0        0.279  118.2184
#
#    Valence  Explicit  Records Artist_clean  Album      Continent    Country  \
# ...

# %%
df_rank = df.loc[df['Rank'] <= 10]


df_rank.head()
# Out:
#    Unnamed: 0  Acousticness  Danceability  Duration Ms  Energy  \
# 1           2       0.11788        0.7372     155645.8  0.6806
# 2           3       0.11788        0.7372     155645.8  0.6806
# 3           4       0.11788        0.7372     155645.8  0.6806
# 5           6       0.11788        0.7372     155645.8  0.6806
# 6           7       0.11788        0.7372     155645.8  0.6806
#
#    Instrumentalness  Liveness  Loudness  Popularity  Speechiness     Tempo  \
# 1               0.0    0.1598    -5.112        72.0        0.279  118.2184
# 2               0.0    0.1598    -5.112        72.0        0.279  118.2184
# 3               0.0    0.1598    -5.112        72.0        0.279  118.2184
# 5               0.0    0.1598    -5.112        72.0        0.279  118.2184
# 6               0.0    0.1598    -5.112        72.0        0.279  118.2184
#
#    Valence  Explicit  Records Artist_clean  Album Continent         Country  \
# ...

# %%
#New--Scatter plot analyzing musicalities by rank
x_values = df_rank['Danceability']
y_values = df_rank['Rank']
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)


plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")


plt.xlabel('Danceability')
plt.ylabel('Rank')
plt.annotate(line_eq,(1,1), fontsize=15,color="red")

print(f"The r-value is: {rvalue**2}")

plt.savefig('DancevRank.png')
plt.show()
# Out:
# y = 0.81x +4.86
# The r-value is: 0.0006062405967284679

# %%
#New--Scatter plot analyzing musicalities by rank
x_values = df_rank['Energy']
y_values = df_rank['Rank']
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)


plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")


plt.xlabel('Energy')
plt.ylabel('Rank')
plt.annotate(line_eq,(1,1), fontsize=15,color="red")

print(f"The r-value is: {rvalue**2}")

plt.savefig('EnergyvRank.png')
plt.show()
# Out:
# y = -1.72x +6.55
# The r-value is: 0.0033431413874137964
