# %%
import pandas as pd
import numpy as np
from pprint import pprint

# %%
#read in csv file
data = pd.read_csv("SpotifyTopSongsByCountry.csv")

# %%
#view data csv
data.head()
# Out:
#   Country Continent  Rank                            Title  \
# 0  Global    Global     1  Rain On Me (with Ariana Grande)
# 1  Global    Global     2                  Blinding Lights
# 2  Global    Global     3     ROCKSTAR (feat. Roddy Ricch)
# 3  Global    Global     4            Roses - Imanbek Remix
# 4  Global    Global     5                     Toosie Slide
#
#                     Artists                            Album  Explicit  \
# 0  Lady Gaga, Ariana Grande  Rain On Me (with Ariana Grande)         0
# 1                The Weeknd                      After Hours         0
# 2       DaBaby, Roddy Ricch                 BLAME IT ON BABY         1
# 3        SAINt JHN, Imanbek            Roses (Imanbek Remix)         1
# 4                     Drake             Dark Lane Demo Tapes         1
#
#   Duration
# 0     3:02
# 1     3:20
# 2     3:01
# 3     2:56
# 4     4:07

# %%
#create a dataframe with only Artists column
artists_df = data[['Artists']]
artists_df
# Out:
#                          Artists
# 0       Lady Gaga, Ariana Grande
# 1                     The Weeknd
# 2            DaBaby, Roddy Ricch
# 3             SAINt JHN, Imanbek
# 4                          Drake
# ...                          ...
# 3145                         Vũ.
# 3146             BigDaddy, Emily
# 3147  Tóc Tiên, Da LAB, Touliver
# 3148                 Bich Phuong
# 3149                  The Weeknd
#
# [3150 rows x 1 columns]

# %%
#clean data to only include one artist name per column (delimiter is a comma)
cleaned_df = artists.Artists.str.split(",", expand=True)
cleaned_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-d2cc2b9db34d> in <module>
#       1 #clean data to only include one artist name per column (delimiter is a comma)
# ----> 2 cleaned_df = artists.Artists.str.split(",", expand=True)
#       3 cleaned_df.head()
#
# NameError: name 'artists' is not defined

# %%
#add row[0], first artist name listed, to the orginial dataframe
data['First Artist'] = cleaned_df[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-012b48ede978> in <module>
#       1 #add row[0], first artist name listed, to the orginial dataframe
# ----> 2 data['First Artist'] = cleaned_df[0]
#
# NameError: name 'cleaned_df' is not defined

# %%
#check to see if first artist column was added
data.head()
# Out:
#   Country Continent  Rank                            Title  \
# 0  Global    Global     1  Rain On Me (with Ariana Grande)
# 1  Global    Global     2                  Blinding Lights
# 2  Global    Global     3     ROCKSTAR (feat. Roddy Ricch)
# 3  Global    Global     4            Roses - Imanbek Remix
# 4  Global    Global     5                     Toosie Slide
#
#                     Artists                            Album  Explicit  \
# 0  Lady Gaga, Ariana Grande  Rain On Me (with Ariana Grande)         0
# 1                The Weeknd                      After Hours         0
# 2       DaBaby, Roddy Ricch                 BLAME IT ON BABY         1
# 3        SAINt JHN, Imanbek            Roses (Imanbek Remix)         1
# 4                     Drake             Dark Lane Demo Tapes         1
#
#   Duration First Artist
# 0     3:02    Lady Gaga
# 1     3:20   The Weeknd
# 2     3:01       DaBaby
# 3     2:56    SAINt JHN
# 4     4:07        Drake

# %%
#get column names for dataframe
for col in data.columns:
    print(col)
# Out:
# Country
# Continent
# Rank
# Title
# Artists
# Album
# Explicit
# Duration
# First Artist

# %%
#reorder columns in dataframe so Artists and First Artist are next to each other
data = data[['Country', 'Continent', 'Rank', 'Title', 'Artists', 'First Artist', 'Album', 'Explicit', 'Duration']]
data
# Out:
#       Country Continent  Rank                            Title  \
# 0      Global    Global     1  Rain On Me (with Ariana Grande)
# 1      Global    Global     2                  Blinding Lights
# 2      Global    Global     3     ROCKSTAR (feat. Roddy Ricch)
# 3      Global    Global     4            Roses - Imanbek Remix
# 4      Global    Global     5                     Toosie Slide
# ...       ...       ...   ...                              ...
# 3145  Vietnam      Asia    46                       ĐÃ TỪNG LÀ
# 3146  Vietnam      Asia    47                Mượn Rượu Tỏ Tình
# 3147  Vietnam      Asia    48                     Ngày Tận Thế
# 3148  Vietnam      Asia    49                     Đi Đu Đưa Đi
# 3149  Vietnam      Asia    50                  Blinding Lights
#
#                          Artists First Artist  \
# 0       Lady Gaga, Ariana Grande    Lady Gaga
# 1                     The Weeknd   The Weeknd
# 2            DaBaby, Roddy Ricch       DaBaby
# ...

# %%
data.to_csv("cleaned_top_song.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-465c3b314f65> in <module>
# ----> 1 data.to_csv("cleaned_top_song.csv")
#
# NameError: name 'data' is not defined
